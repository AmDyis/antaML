# %%
pip install catboost
pip install pandas
pip install numpy
pip install matplotlib
pip install scikit-learn
pip install openpyxl
pip install folium
# Out:
# Requirement already satisfied: catboost in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (1.2.5)
# Requirement already satisfied: graphviz in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (3.8.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (5.22.0)
# Requirement already satisfied: six in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from plotly->catboost) (8.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (1.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: openpyxl in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from folium) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uiop1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from catboost import CatBoostRegressor, Pool

# Загрузка данных о средней температуре и координатах станций
dfMid = pd.read_excel('Средняя и коорды.xlsx', sheet_name='Лист1')
dfYear = pd.read_excel("Ежегодная.xlsx", sheet_name='Лист1')

# Заполнение пропущенных значений в данных о ежегодной температуре средними
dfYear.fillna(dfYear.mean(), inplace=True)

# Транспонирование данных и установка годов в качестве индекса
dfYear = dfYear.T
dfYear.columns = dfYear.iloc[0]
dfYear = dfYear[1:]
dfYear = dfYear.astype(float)

# Создание модели K-средних
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=0)

# Кластеризация на координатах станций
cluster_labels = kmeans.fit_predict(dfMid[['Широта', 'Долгота', 'Высота над уровнем моря', 'средняя температура']])
dfMid["Cluster"] = cluster_labels

# Установка индекса 'станция' в DataFrame
dfMid.set_index('станция', inplace=True)

# Объединение данных
merged_df = dfYear.join(dfMid["Cluster"])
merged_df = merged_df.astype(float)

# Вывод результата
print(merged_df.head())

# Разделение данных на обучающий и валидационный наборы
train_data, val_data, train_y, val_y = train_test_split(merged_df.drop(2022.0, axis=1), merged_df[2022.0], test_size=0.3)

# Создание объекта CatBoostRegressor
cat = CatBoostRegressor(iterations=150, depth=3, learning_rate=0.1, loss_function='RMSE', l2_leaf_reg=5, border_count=32, verbose=0)

# Преобразование данных в catboost.Pool
train_pool = Pool(data=train_data, label=train_y)
val_pool = Pool(data=val_data, label=val_y)

# Обучение модели
cat.fit(train_pool)

# # Предсказания
# predictions = cat.predict(train_data)
# print("Предсказанные значения на обучающих данных:")
# print(predictions)
# print("Реальные значения на обучающих данных:")
# print(train_y)

# predictions = cat.predict(val_data)
# print("Предсказанные значения на валидационных данных:")
# print(predictions)
# print("Реальные значения на валидационных данных:")
# print(val_y)
# Out:
#                      2001.0       2002.0      2003.0   2004.0       2005.0  \
# станция          2001.00000  2002.000000  2003.00000  2004.00  2005.000000
# Ago-4             -52.56000   -52.560000   -52.56000   -52.56   -52.560000
# Baia Terra Nova   -14.60000   -13.953846   -14.50000   -13.80   -13.953846
# Baldrick Aws      -37.99000   -37.990000   -37.99000   -37.99   -37.990000
# Base Brown         -2.58125    -2.581250    -2.58125    -2.30    -3.500000
#
#                       2006.0       2007.0       2008.0   2009.0   2010.0  ...  \
# станция          2006.000000  2007.000000  2008.000000  2009.00  2010.00  ...
# Ago-4             -52.560000   -52.560000   -52.560000   -52.56   -52.56  ...
# Baia Terra Nova   -13.953846   -13.953846   -13.953846   -13.60   -13.90  ...
# Baldrick Aws      -37.990000   -37.990000   -37.990000   -37.99   -37.99  ...
# Base Brown         -3.300000    -2.100000     1.200000    -2.90    -4.80  ...
#
#                   2014.0   2015.0  2016.0  2017.0  2018.0  2019.0  \
# станция          2014.00  2015.00  2016.0  2017.0  2018.0  2019.0
# Ago-4             -52.56   -52.56   -53.1   -53.1   -51.1   -53.6
# Baia Terra Nova   -13.40   -14.60   -15.4   -13.8   -13.6   -12.8
# Baldrick Aws      -39.10   -36.70   -37.7   -38.5   -36.6   -38.0
# Base Brown         -2.30    -3.10    -3.1    -3.3    -2.4    -3.6
#
#                       2020.0       2021.0       2022.0  Cluster
# станция          2020.000000  2021.000000  2022.000000      NaN
# Ago-4             -51.900000   -52.560000   -52.560000      4.0
# Baia Terra Nova   -13.953846   -13.953846   -13.953846      2.0
# Baldrick Aws      -38.000000   -37.990000   -38.800000      3.0
# Base Brown         -3.000000    -2.581250    -1.300000      2.0
#
# [5 rows x 23 columns]
# Предсказанные значения на обучающих данных:
# [-28.56254185  -7.35560408 -41.80612014 -52.01600593 -22.84320339
#   -1.26971201 -24.07280248 -23.03408647  -5.75847628 -28.28847087
#  -49.88256696  -2.91365399 -19.93756868  -1.90897595 -15.21083002
#   -2.03109053 -21.5107333  -13.08017721 -16.69060951 -19.54107129
#  -16.78462931 -10.37099364 -23.1587445  -23.31289454 -18.43981677
#  -24.17223781 -47.87461246 -22.10594006 -15.05537067 -22.66176386
#  -25.89792881  -8.2431575  -52.082028   -10.08385522]
# Реальные значения на обучающих данных:
# Byrd Station         -27.400000
# Fossil Bluff          -6.700000
# Купол Плато Орла     -42.300000
# Dome Fuji            -52.280000
# Marilyn              -22.736842
# Кинг Седжон           -0.700000
# Elizabeth            -24.245000
# Ellsworth Station    -23.700000
# Destacamento Naval    -6.200000
# Gill                 -27.980000
# Купол Фудзи          -50.000000
# Centro Metan          -2.800000
# Law Dome Summit      -20.012500
# Фрей                  -1.800000
# Станция Ноймайер     -15.600000
# Dinamet-Уругвай       -1.925000
# Linda                -21.772727
# Baia Terra Nova      -13.953846
# Мыс Филлипс          -16.700000
# Халли                -18.700000
# Halvfarryggen Ep11   -17.075000
# Maitri               -10.145000
# Harry                -23.225000
# Minna Bluff          -23.290000
# Manuela              -18.155556
# D-47                 -24.570000
# Nico                 -47.553846
# Ferrell              -22.166667
# Мыс Росс             -14.500000
# Elaine               -22.676923
# Lettau               -26.105000
# Кейси                 -9.100000
# Ago-4                -52.560000
# Дэвис                 -9.300000
# Name: 2022.0, dtype: float64
# Предсказанные значения на валидационных данных:
# [-14.61483551  -3.67121551 -15.15566036 -13.70501372 -52.082028
#   -1.71410402  -3.37664396  -1.74753771 -41.80612014 -41.87344612
#  -47.87461246  -1.26971201 -26.02081816 -49.92634485 -15.48681509]
# Реальные значения на валидационных данных:
# Casey (Peterson air)           -14.400000
# Bonaparte Parkpoint             -3.158824
# Base Roi Baudouin              -17.100000
# D-10                           -13.650000
# Davis АМС                      -56.900000
# База капитана Артуро Прата      -0.700000
# Base Brown                      -1.300000
# станция                       2022.000000
# Kohnen Ep9                     -41.128571
# Baldrick Aws                   -38.800000
# Henry АМС                      -46.590000
# Карлини                         -0.400000
# Byrd АМС                       -26.450000
# Dome C                         -50.300000
# Марбл-Пойнт                    -14.300000
# Name: 2022.0, dtype: float64

# %%
import folium
import pandas as pd

m = folium.Map(location=[0, 0], zoom_start=2)
# Задайте координаты (широта и долгота) точки
df = pd.read_excel('Средняя и коорды.xlsx', sheet_name='Лист1')
# print(df["Долгота"], df["Широта"])
points = []
for i in range(len(df["станция"])):
    df['станция'][i] = df["станция"][i].replace('`', "\`")
    points.append({"name": df["станция"][i], "latitude": df["Широта"][i], "longitude": df["Долгота"][i], "temperature": df["средняя температура"][i]})
print(points)
# Создайте объект карты
for point in points:
    tooltip_text = f"{point['name']} (Средняя температура: {point['temperature']}°C)"
    folium.Marker([point["latitude"], point["longitude"]], tooltip=tooltip_text).add_to(m)
# Отобразите карту в браузере
m.save('map.html')  # Сохраните карту в HTML-файл и откройте его в браузере
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\`'
# <>:10: SyntaxWarning: invalid escape sequence '\`'
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SyntaxWarning: invalid escape sequence '\`'
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# [{'name': 'Ago-4', 'latitude': -82.02, 'longitude': 96.77, 'temperature': -52.6}, {'name': 'Baia Terra Nova', 'latitude': -74.7, 'longitude': 164.1, 'temperature': -14.1}, {'name': 'Baldrick Aws', 'latitude': -82.77, 'longitude': -13.05, 'temperature': -38.0}, {'name': 'Base Brown', 'latitude': -64.88, 'longitude': -62.88, 'temperature': -2.6}, {'name': 'Base Roi Baudouin', 'latitude': -70.4, 'longitude': 24.3, 'temperature': -15.8}, {'name': 'Bonaparte Parkpoint', 'latitude': -64.78, 'longitude': -63.07, 'temperature': -2.8}, {'name': 'Byrd Station', 'latitude': -80.02, 'longitude': -119.53, 'temperature': -27.7}, {'name': 'Byrd АМС', 'latitude': -80.0, 'longitude': -119.4, 'temperature': -27.1}, {'name': 'Мыс Филлипс', 'latitude': -73.51, 'longitude': 169.75, 'temperature': -16.9}, {'name': 'Мыс Росс', 'latitude': -76.71, 'longitude': 162.96, 'temperature': -15.4}, {'name': 'База капитана Артуро Прата', 'latitude': -62.5, 'longitude': -59.68, 'temperature': -2.3}, {'name': 'Карлини', 'latitude': -62.23, 'longitude': -58.63, 'temperature': -1.6}, {'name': 'Кейси', 'latitude': -66.28, 'longitude': 110.51, 'temperature': -9.2}, {'name': 'Casey (Peterson air)', 'latitude': -66.6, 'longitude': 111.18, 'temperature': -14.4}, {'name': 'Centro Metan', 'latitude': -62.42, 'longitude': -58.88, 'temperature': -2.5}, {'name': 'D-10', 'latitude': -66.71, 'longitude': 139.83, 'temperature': -13.4}, {'name': 'D-47', 'latitude': -67.38, 'longitude': 138.71, 'temperature': -24.5}, {'name': 'Дэвис', 'latitude': -68.58, 'longitude': 77.95, 'temperature': -10.1}, {'name': 'Davis АМС', 'latitude': -80.36, 'longitude': 77.37, 'temperature': -54.3}, {'name': 'Destacamento Naval', 'latitude': -63.0, 'longitude': -60.7, 'temperature': -3.0}, {'name': 'Dinamet-Уругвай', 'latitude': -62.18, 'longitude': -58.83, 'temperature': -2.0}, {'name': 'Dome C', 'latitude': -74.5, 'longitude': 123.0, 'temperature': -50.6}, {'name': 'Купол Фудзи', 'latitude': -75.12, 'longitude': 123.37, 'temperature': -50.9}, {'name': 'Dome Fuji', 'latitude': -77.32, 'longitude': 39.7, 'temperature': -52.4}, {'name': 'Купол Плато Орла', 'latitude': -76.41, 'longitude': 77.02, 'temperature': -42.6}, {'name': 'Elaine', 'latitude': -83.13, 'longitude': 174.47, 'temperature': -22.9}, {'name': 'Elizabeth', 'latitude': -82.61, 'longitude': -137.0, 'temperature': -24.3}, {'name': 'Ellsworth Station', 'latitude': -77.7, 'longitude': -41.1, 'temperature': -23.1}, {'name': 'Ferrell', 'latitude': -77.88, 'longitude': 170.81, 'temperature': -22.4}, {'name': 'Fossil Bluff', 'latitude': -71.33, 'longitude': -68.35, 'temperature': -9.2}, {'name': 'Фрей', 'latitude': -62.18, 'longitude': -58.98, 'temperature': -2.3}, {'name': 'Gill', 'latitude': -75.5, 'longitude': -26.65, 'temperature': -28.2}, {'name': 'Халли', 'latitude': -75.5, 'longitude': -26.65, 'temperature': -18.8}, {'name': 'Halvfarryggen Ep11', 'latitude': -71.15, 'longitude': -6.68, 'temperature': -17.1}, {'name': 'Harry', 'latitude': -83.0, 'longitude': -121.3, 'temperature': -23.2}, {'name': 'Henry АМС', 'latitude': -89.0, 'longitude': -1.03, 'temperature': -46.8}, {'name': 'Кинг Седжон', 'latitude': -62.21, 'longitude': -58.75, 'temperature': -1.7}, {'name': 'Kohnen Ep9', 'latitude': -75.0, 'longitude': 0.0, 'temperature': -41.1}, {'name': 'Law Dome Summit', 'latitude': -66.73, 'longitude': 112.75, 'temperature': -20.0}, {'name': 'Lettau', 'latitude': -82.51, 'longitude': -174.4, 'temperature': -26.2}, {'name': 'Linda', 'latitude': -78.45, 'longitude': 168.39, 'temperature': -21.8}, {'name': 'Maitri', 'latitude': -70.76, 'longitude': 11.75, 'temperature': -9.9}, {'name': 'Manuela', 'latitude': -74.94, 'longitude': 163.68, 'temperature': -18.3}, {'name': 'Марбл-Пойнт', 'latitude': -77.43, 'longitude': 163.75, 'temperature': -16.0}, {'name': 'Marilyn', 'latitude': -79.95, 'longitude': 165.13, 'temperature': -23.0}, {'name': 'Minna Bluff', 'latitude': -78.55, 'longitude': 166.7, 'temperature': -22.9}, {'name': 'Станция Ноймайер', 'l ...
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
# C:\Users\uiop1\AppData\Local\Temp\ipykernel_8980\387123281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['станция'][i] = df["станция"][i].replace('`', "\`")
